# %%
import pandas as pd

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
df = pd.read_csv('household_power_consumption.txt', sep=';', 
                 parse_dates={'dt' : ['Date', 'Time']}, infer_datetime_format=True, 
                 low_memory=False, na_values=['nan','?'], index_col='dt')

df.shape
# Out:
# (2075259, 7)

# %%
df.isnull().sum()
# Out:
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# dtype: int64

# %%
df = df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

i = 1
cols=[0, 1, 3, 4, 5, 6]
plt.figure(figsize=(20, 10))
for col in cols:
    plt.subplot(len(cols), 1, i)
    plt.plot(df.resample('M').mean().values[:, col])
    plt.title(df.columns[col] + ' data resample over month for mean', y=0.75, loc='left')
    i += 1
plt.show()

# %%
i = 1
cols=[0, 1, 3, 4, 5, 6]
plt.figure(figsize=(20, 10))
for col in cols:
    plt.subplot(len(cols), 1, i)
    plt.plot(df.resample('D').mean().values[:, col])
    plt.title(df.columns[col] + ' data resample over day for mean', y=0.75, loc='center')
    i += 1
plt.show()

# %%
i = 1
cols=[0, 1, 3, 4, 5, 6]
plt.figure(figsize=(20, 10))
for col in cols:
    plt.subplot(len(cols), 1, i)
    plt.plot(df.resample('H').mean().values[:, col])
    plt.title(df.columns[col] + ' data resample over hour for mean', y=0.75, loc='left')
    i += 1
plt.show()

# %%
df = df[['Global_active_power', 'Global_reactive_power', 'Voltage',
       'Global_intensity', 'Sub_metering_2', 'Sub_metering_1','Sub_metering_3']]
       
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    dff = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(dff.shift(-i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(dff.shift(-i))
        if i==0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1)) for j in range(n_vars)]        
        agg = pd.concat(cols, axis=1)
        agg.columns = names
        if dropnan:
            agg.dropna(inplace=True)
        return agg

# %%
df_resample = df.resample('h').mean() 
df_resample.shape
# Out:
# (34589, 7)

# %%
from sklearn.preprocessing import MinMaxScaler

values = df_resample.values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1)
r = list(range(df_resample.shape[1]+1, 2*df_resample.shape[1]))
reframed.drop(reframed.columns[r], axis=1, inplace=True)
reframed.head()

# Data spliting into train and test data series. Only 4000 first data points are selected for traing purpose.
values = reframed.values
n_train_time = 4000
train = values[:n_train_time, :]
test = values[n_train_time:, :]
train_x, train_y = train[:, :-1], train[:, -1]
test_x, test_y = test[:, :-1], test[:, -1]
train_x = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))
test_x = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\maria\anaconda3\lib\site-packages (2.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\maria\anaconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: setuptools in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (45.2.0.post20200210)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: packaging in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (20.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: six>=1.12.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.46.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (3.20.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\maria\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\maria\anaconda3\lib\site-packages (from packaging->tensorflow) (2.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\maria\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.34.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\maria\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.1.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\maria\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\maria\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\maria\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.6.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\maria\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\maria\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\maria\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maria\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\maria\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.25.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\maria\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\maria\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\maria\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\maria\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.1.0)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\maria\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.11.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\maria\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\maria\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\maria\anaconda3\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt
import numpy as np

model = Sequential()
model.add(LSTM(100, input_shape=(train_x.shape[1], train_x.shape[2])))
model.add(Dropout(0.1))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Network fitting
history = model.fit(train_x, train_y, epochs=50, batch_size=70, validation_data=(test_x, test_y), verbose=2, shuffle=False)

# Loss history plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

size = df_resample.shape[1]

# Prediction test
yhat = model.predict(test_x)
test_x = test_x.reshape((test_x.shape[0], size))

# invert scaling for prediction
inv_yhat = np.concatenate((yhat, test_x[:, 1-size:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_x[:, 1-size:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)

aa=[x for x in range(500)]
plt.figure(figsize=(25,10)) 
plt.plot(aa, inv_y[:500], marker='.', label="actual")
plt.plot(aa, inv_yhat[:500], 'r', label="prediction")
plt.ylabel(df.columns[0], size=15)
plt.xlabel('Time step for first 500 hours', size=15)
plt.legend(fontsize=15)
plt.show()
# Out:
# Epoch 1/50
# 58/58 - 3s - loss: 0.0255 - val_loss: 0.0103 - 3s/epoch - 47ms/step
# Epoch 2/50
# 58/58 - 1s - loss: 0.0149 - val_loss: 0.0100 - 746ms/epoch - 13ms/step
# Epoch 3/50
# 58/58 - 1s - loss: 0.0139 - val_loss: 0.0099 - 823ms/epoch - 14ms/step
# Epoch 4/50
# 58/58 - 1s - loss: 0.0133 - val_loss: 0.0098 - 800ms/epoch - 14ms/step
# Epoch 5/50
# 58/58 - 1s - loss: 0.0128 - val_loss: 0.0096 - 814ms/epoch - 14ms/step
# Epoch 6/50
# 58/58 - 1s - loss: 0.0125 - val_loss: 0.0095 - 838ms/epoch - 14ms/step
# Epoch 7/50
# 58/58 - 1s - loss: 0.0122 - val_loss: 0.0094 - 830ms/epoch - 14ms/step
# Epoch 8/50
# 58/58 - 1s - loss: 0.0121 - val_loss: 0.0094 - 827ms/epoch - 14ms/step
# Epoch 9/50
# 58/58 - 1s - loss: 0.0121 - val_loss: 0.0093 - 782ms/epoch - 13ms/step
# Epoch 10/50
# 58/58 - 1s - loss: 0.0120 - val_loss: 0.0093 - 740ms/epoch - 13ms/step
# Epoch 11/50
# 58/58 - 1s - loss: 0.0118 - val_loss: 0.0092 - 786ms/epoch - 14ms/step
# Epoch 12/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0092 - 815ms/epoch - 14ms/step
# Epoch 13/50
# 58/58 - 1s - loss: 0.0118 - val_loss: 0.0092 - 901ms/epoch - 16ms/step
# Epoch 14/50
# 58/58 - 1s - loss: 0.0118 - val_loss: 0.0091 - 751ms/epoch - 13ms/step
# Epoch 15/50
# 58/58 - 1s - loss: 0.0118 - val_loss: 0.0091 - 727ms/epoch - 13ms/step
# Epoch 16/50
# 58/58 - 1s - loss: 0.0118 - val_loss: 0.0091 - 779ms/epoch - 13ms/step
# Epoch 17/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 821ms/epoch - 14ms/step
# Epoch 18/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 733ms/epoch - 13ms/step
# Epoch 19/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 743ms/epoch - 13ms/step
# Epoch 20/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 777ms/epoch - 13ms/step
# Epoch 21/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 787ms/epoch - 14ms/step
# Epoch 22/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 788ms/epoch - 14ms/step
# Epoch 23/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 776ms/epoch - 13ms/step
# Epoch 24/50
# 58/58 - 1s - loss: 0.0117 - val_loss: 0.0091 - 818ms/epoch - 14ms/step
# Epoch 25/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 813ms/epoch - 14ms/step
# Epoch 26/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 827ms/epoch - 14ms/step
# Epoch 27/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0090 - 798ms/epoch - 14ms/step
# Epoch 28/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 786ms/epoch - 14ms/step
# Epoch 29/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0090 - 820ms/epoch - 14ms/step
# Epoch 30/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 806ms/epoch - 14ms/step
# Epoch 31/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 790ms/epoch - 14ms/step
# Epoch 32/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 762ms/epoch - 13ms/step
# Epoch 33/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 902ms/epoch - 16ms/step
# Epoch 34/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 801ms/epoch - 14ms/step
# Epoch 35/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 810ms/epoch - 14ms/step
# Epoch 36/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 832ms/epoch - 14ms/step
# Epoch 37/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 795ms/epoch - 14ms/step
# Epoch 38/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 790ms/epoch - 14ms/step
# Epoch 39/50
# 58/58 - 1s - loss: 0.0114 - val_loss: 0.0091 - 814ms/epoch - 14ms/step
# Epoch 40/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 839ms/epoch - 14ms/step
# Epoch 41/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 817ms/epoch - 14ms/step
# Epoch 42/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0091 - 767ms/epoch - 13ms/step
# Epoch 43/50
# 58/58 - 1s - loss: 0.0116 - val_loss: 0.0091 - 775ms/epoch - 13ms/step
# Epoch 44/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 819ms/epoch - 14ms/step
# Epoch 45/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 827ms/epoch - 14ms/step
# Epoch 46/50
# 58/58 - 1s - loss: 0.0114 - val_loss: 0.0090 - 824ms/epoch - 14ms/step
# Epoch 47/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 815ms/epoch - 14ms/step
# Epoch 48/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 781ms/epoch - 13ms/step
# Epoch 49/50
# 58/58 - 1s - loss: 0.0115 - val_loss: 0.0090 - 783ms/epoch - 13ms/step
# Epoch 50/50
# 58/58 - 1s - loss: 0.0114 - val_loss: 0.0090 - 839ms/epoch - 14ms/step
# 956/956 [==============================] - 2s 1ms/step
# Test RMSE: 0.611
